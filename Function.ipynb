# %% [markdown]
# # Function in python

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#   A function is a structured, reusable code block utilized for carrying out a specific task, a method is also ablock of code that performs a specific task but it is defined with a class and is associated with the object of that class
#
# 2. Explain the concept of function arguments and parameters in Python?
#   parameters act as placeholders for the data the function will operate on, while arguments are the real data values supplied during the fuction call.
#
# 3. What are the different ways to define and call a function in Python?
#   following are the ways to define and call a function in python
#    1. Standard function Definition (def)
#    2. Lambda Functions (lambda)
#    3. Map function(map)
#    4. Reduce function (reduce)
#
# 4. What is the purpose of the `return` statement in a Python function?
#   'return' statement determines the value that the function will return. If not included, the function defaults to returning None.
#
# 5. What are iterators in Python and how do they differ from iterables?
#    an iterator is an object representing a stream of data, an iterable is any python object/sequential structure/ data structure that is capable of its members one at a time.
#
# 6. Explain the concept of generators in Python and how they are defined?
#   Generators are a simple way to create iterators using functions and the yield keyword instead of returning values.
#
# 7. What are the advantages of using generators over regular functions?
#    Regular function memory usage is more and it will take a lot of exicution time then generator function this makes them ideal for handling large datasets.
#
# 8. What is a lambda function in Python and when is it typically used?
#   Lambda functions are small, anonymous functions defined using the lambda keyword. They are used for creating small, throwaway functions without the need to formally define a function using def.
#
# 9. Explain the purpose and usage of the `map()` function in Python.
#   Executes a specified function for each of iteam of an iterable.
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()`
#   functions in Python?
#   map function used to transform each item in an iterable by applying the specified function.
#   reduce function reduces an iterable to a single cumulative value by applying the function cumulatively.
#   filter function used for filtering elements from an iterable based on a condition defined by the function.
#
# 11. Using pen & Paper write the internal mechanism for sum operation using
#   reduce function on this given
#   list:[47,11,42,13];
#
#
# ![20250521_143642.jpg](data:image/jpeg;base64,...)

# %%
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.
def sum(numbers):
  num = int(input("write a no of list : "))
  return sum(num for num in numbers if num % 2 == 0)

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string.
def para(s):
    s = s.lower().replace(" ", "")
    return s == s[::-1]

para("ma d   a  m")
# Out:
# True

# %%
para("palak")
# Out:
# False

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.
def squ(n):
    result = []
    for i in n:
        result.append(i ** 2)
    return result
squ([2, 4, 6, 7, 9])
# Out:
# [4, 16, 36, 49, 81]

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.
def fib(n):
    a = 0
    b = 1
    for i in range(n):
        yield a
        a, b = b, a+b

# %%
f = fib(10)
f
# Out:
# <generator object fib at 0x7d217307d120>

# %%
next(f)
# Out:
# 0

# %%
next(f)
# Out:
# 1

# %%
next(f)
# Out:
# 1

# %%
next(f)
# Out:
# 2

# %%
next(f)
# Out:
# 3

# %%
next(f)
# Out:
# 5

# %%
# Write a generator function in Python that yields the powers of 2 up to a given exponent.
def squ(n):
    for i in range(n):
        yield i**2

# %%
squ(10)
# Out:
# <generator object squ at 0x7d217308a4d0>

# %%
gen = squ(10)
gen
# Out:
# <generator object squ at 0x7d217308bc60>

# %%
next(gen)
# Out:
# 0

# %%
next(gen)
# Out:
# 1

# %%
next(gen)
# Out:
# 4

# %%
#  Implement a generator function that reads a file line by line and yields each line as a string.

# %%
# Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit
l =[3, 4,6]
def cel(x):
  return x*2+30

list(map(cel,l))
# Out:
# [36, 38, 42]
